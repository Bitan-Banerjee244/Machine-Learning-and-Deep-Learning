# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
employee = {
    "experience":[1,2,3,4,5],
    "salary":[30000,35000,45000,50000,60000]
}

df = pd.DataFrame(employee)
df
# Out:
#    experience  salary
# 0           1   30000
# 1           2   35000
# 2           3   45000
# 3           4   50000
# 4           5   60000

# %%
y = df['salary']
X = df[['experience']]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
print(f"Slope = {model.coef_}")
print(f"Intercept = {model.intercept_}")
# Out:
# Slope = [7500.]
# Intercept = 21500.000000000007

# %%
predictions = model.predict([[6]])
print(predictions)
# Out:
# [66500.]

# %%
plt.scatter(X,y,marker = "o" , color = "seagreen")
plt.plot(X,model.predict(X),color = "red")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary Price Predictions")

# Predition of 6 year experience salary
plt.scatter(6,predictions,marker = "X",color = "Orange")

plt.grid(True)
plt.show()
